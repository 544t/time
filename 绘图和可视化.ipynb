# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
fig = plt.figure()#创建画布
ax = fig.add_subplot(2,2,1)#创建画布
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
ax.plot(np.random.randn(100).cumsum(),'k--')
ax2.hist(np.random.randn(100),bins = 10)
x = np.random.rand(20)
y = np.random.rand(20)
ax4.scatter(x,y)

x = [1,2,3,4,5]
y = [2,5,3,7,8]
ax3.scatter(x,y)
ax3.text(5,8,'the king')
# plt.close('all')
# Out:
# Text(5,8,'the king')

# %%
fig = plt.figure()
fig1  = fig.add_subplot(1,1,1)
plt.subplots_adjust(wspace = 0,hspace = 0)#调整每个subplot之间的间距
# ax = axes[1]
fig1.plot(np.random.randn(100).cumsum(),'go--')
#修改坐标轴标签
ticks = fig1.set_xticks([0,30,50,80,100])
labels = fig1.set_xticklabels(['one','two','three','four','five'])
label = fig1.set_xlabel('aaaa')#X轴标题
title = fig1.set_title('my_plot')#标题

#用集合进行修改(高级！)
p = {'title':'my_pplot',
    'ylabel':'bbbbbb'}
fig1.set(**p)
# Out:
# [Text(0,0.5,'bbbbbb'), Text(0.5,1,'my_pplot')]

# %%
#创建图例
fig = plt.figure()
data = np.random.randn(30).cumsum()
#在同一张图上画两种线
plt.plot(data,'g--',label = 'aaaa')
plt.plot(data,'k-',label = 'bbbb',drawstyle = 'steps-post')
plt.legend(loc = 'best')
# plt.show()

# %%
#创建图例
fig = plt.figure()
data = np.random.randn(200).cumsum()
data2 = np.random.randn(200).cumsum()
#在同一张图上画两种线
plt.plot(data,'go-',label = 'aaaa')
plt.plot(data2,'ko-',label = 'bbbb',drawstyle = 'steps-post')
plt.legend(loc = 'best')

# %%
from datetime import datetime
#创建画布
fig = plt.figure()
fig1 = fig.add_subplot(1,1,1)
#读取数据
data = pd.read_csv(r'C:\Users\123\Desktop\spx.csv')
print(data.head())
spx = data['SPX']

spx.plot(ax = ax,style = 'k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]
for data,label in crisis_data:
    ax.annotate(label,xy = (data, spx.asof(data)+75),
               xytext = (data,spx.asof(data)+225),
               arrowprops = dict(facecolor = 'black',headwidth = 4,
                                width =2,headlength = 4),
               horizontalalignment='left', verticalalignment='top')
    
ax.set_xlim(['1/1/2007','1/1/2011'])
ax.set_ylim([600,1800])
ax.set_title('very_important')
# Out:
#             Unnamed: 0     SPX
# 0  1990-02-01 00:00:00  328.79
# 1  1990-02-02 00:00:00  330.92
# 2  1990-02-05 00:00:00  331.85
# 3  1990-02-06 00:00:00  329.66
# 4  1990-02-07 00:00:00  333.75
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0ebb0426ce0f> in <module>()
#      16 ]
#      17 for data,label in crisis_data:
# ---> 18     ax.annotate(label,xy = (data, spx.asof(data)+75),
#      19                xytext = (data,spx.asof(data)+225),
#      20                arrowprops = dict(facecolor = 'black',headwidth = 4,
#
# D:\anaconda3\lib\site-packages\pandas\core\generic.py in asof(self, where, subset)
#    6110                 start = start.ordinal
#    6111
# -> 6112             if where < start:
#    6113                 if not is_series:
#    6114                     from pandas import Series
#
# ...

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv(r'C:\Users\123\Desktop\spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,'Important dates in the 2008-2009 financial crisis')

# %%
#画图形
fig = plt.figure()
fig1 = fig.add_subplot(1,1,1)
#三角形
rect = plt.Rectangle((0.2,0.75,),0.4,0.75,color = 'k',alpha = 0.3)
#圆形
cric = plt.Circle((0.7,0.2),0.15,color = 'b',alpha = 0.3)
#方形
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)
fig1.add_patch(rect)
fig1.add_patch(cric)
fig1.add_patch(pgon)
plt.savefig(r'C:\Users\123\Desktop\aaaaaaaaaaaaaaaaaa.png')

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
df.plot()

# %%
fig,axes = plt.subplots(2,1)
data = pd.Series(np.random.rand(16),index = list('abcdefghijklmnop'))
data.plot.bar(ax = axes[0],color = 'k',alpha = 0.7)
data.plot.barh(ax = axes[1],color = 'k',alpha = 0.7)

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
df.plot.bar()

# %%
plt.figure()
df.plot.barh(stacked = True, alpha = 0.6)

# %%
tips = pd.read_csv(r'C:\Users\123\Desktop\tips.csv')
print(tips.head())
#交叉表
cross = pd.crosstab(tips['day'],tips['size'])
print(cross)
cross = cross.loc[:,2:5]
print(cross)
pp = cross.div(cross.sum(1),axis = 0)
print(pp)
pp.plot.bar()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
import seaborn as sns
tips['tip_pct'] = tips['tip']/(tips['total_bill']-tips['tip'])
print(tips.head())
sns.barplot(x = 'tip_pct',y = 'day',data = tips, orient = 'h')
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069
# D:\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.barplot(x = 'tip_pct',y = 'day',hue = 'time',data = tips, orient = 'h')
# Out:
# D:\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
tips['tip_pct'].plot.hist(bins=50)

# %%
tips['tip_pct'].plot.density()

# %%
#小费百分比的密度图
cmp1 = np.random.normal(0,1,size = 200)
cmp2 = np.random.normal(10,2,size = 200)
values = pd.Series(np.concatenate([cmp1,cmp2]))
sns.distplot(values,bins = 100,color = 'k')
# Out:
# D:\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#散点图
ma = pd.read_csv(r'C:\Users\123\Desktop\macrodata.csv')
data = ma[['cpi', 'm1', 'tbilrate', 'unemp']]
tr = np.log(data).diff().dropna()
tr[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
sns.regplot('m1','unemp',data = tr)
# Out:
# D:\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(tr,diag_kind='kde',plot_kws={'alpha':0.2})
# Out:
# D:\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.factorplot(x = 'day',y = 'tip_pct',col = 'smoker',
              kind = 'bar',data = tips[tips['tip_pct']<1],
              hue = 'time')
# Out:
# D:\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.factorplot(x='day',y='tip_pct',row = 'time',col = 'smoker',kind='bar',
              data = tips[tips['tip_pct']<1])
# Out:
# D:\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# D:\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#hue的作用
sns.factorplot(x='tip_pct',y='day',kind='box',hue = 'smoker',
              data=tips[tips['tip_pct']<0.5])
# Out:
# D:\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='tip_pct',y='day',kind='box',
              data=tips[tips['tip_pct']<0.5])
# Out:
# D:\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
